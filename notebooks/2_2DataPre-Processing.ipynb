# %%
import os

# %%
os.makedirs(os.path.join('..', 'data', '2_2Testdata'), exist_ok = True)
data_file = os.path.join('..', 'data', '2_2Testdata', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n')
    f.write('NA,Pave,127500\n')
    f.write('2,NA,10600\n')
    f.write('4,NA,114514\n')
    f.write('NA,NA,12000\n')

# %%
import pandas as pd
data = pd.read_csv(data_file)
print(data)
type(data)
# Out:
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN   10600
# 2       4.0   NaN  114514
# 3       NaN   NaN   12000
# pandas.DataFrame

# %%
inputs, outputs = data.iloc[:, 0:2], data.iloc[:, 2]
print(inputs.dtypes)
if 'NumRooms' in inputs.columns:
    inputs['NumRooms'] = inputs['NumRooms'].fillna(inputs['NumRooms'].mean())
print(inputs)
# Out:
# NumRooms    float64
# Alley           str
# dtype: object
#    NumRooms Alley
# 0       3.0  Pave
# 1       2.0   NaN
# 2       4.0   NaN
# 3       3.0   NaN

# %%
inputs = pd.get_dummies(inputs, dummy_na = True)
print(inputs)
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0       3.0        True      False
# 1       2.0       False       True
# 2       4.0       False       True
# 3       3.0       False       True

# %%
import torch
inputs = inputs.astype(float)
x, y = torch.tensor(inputs.values), torch.tensor(outputs.values)
x, y
# Out:
# (tensor([[3., 1., 0.],
#          [2., 0., 1.],
#          [4., 0., 1.],
#          [3., 0., 1.]], dtype=torch.float64),
#  tensor([127500,  10600, 114514,  12000]))
